# %%
person = {
    "person1" : {
    "first_name" : "Malik",
    "last_name" : "Anas",
    "age" : 47,
    "hometown" : "London",
    "favourite_foods" : ["Fried Rice", "Pizza", "Spaghetti"],
    "hobbies" : ["reading", "painting", "cooking"]
 },
    "person2" : {
    "first_name" : "Gianluca",
    "last_name" : "Farrell",
    "age" : 33,
    "hometown" : "Seychelles",
    "favourite_foods" : ["Chocolate", "Sushi", "Hamburger"],
    "hobbies" : ["dance", "fishkeeping", "hunting"]
 },
    "person3": {
    "first_name" : "Martina",
    "last_name" : "Nielsen",
    "age" : 21,
    "hometown" : "Sydney",
    "favourite_foods" : ["Assam Laksa", "Ice cream", "Donuts"],
    "hobbies" : ["singing", "cycling", "traveling"]   
 },
    "person4" : {
    "first_name" : "Martina",
    "last_name" : "Nielsen",
    "age" : 25,
    "hometown" : "Sydney",
    "favourite_foods" : ["Assam Laksa", "Ice cream", "Donuts"],
    "hobbies" : ["singing", "cycling", "traveling"]     
 },
    "person5" : {
    "first_name" : "Anisha",
    "last_name" : "Mahoney",
    "age" : 30,
    "hometown" : "Paris",
    "favourite_foods" : ["Lobster", "Croissant", "Lasagna"],
    "hobbies" : ["baking", "scuba diving", "crochet"]    
 }
}

# %%
for person_id, person_info in person.items():
    print(f"Person {person_id}:")
    for key, value in person_info.items():
        if key == "favourite_foods" or key == "hobbies":
            print(f"{key.capitalize()}:")
            for item in value:
                print(f"- {item}")
        else:
            print(f"{key.capitalize()}: {value}")
    print()
# Out:
# Person person1:
# First_name: Malik
# Last_name: Anas
# Age: 47
# Hometown: London
# Favourite_foods:
# - Fried Rice
# - Pizza
# - Spaghetti
# Hobbies:
# - reading
# - painting
# - cooking
#
# Person person2:
# First_name: Gianluca
# Last_name: Farrell
# Age: 33
# Hometown: Seychelles
# Favourite_foods:
# - Chocolate
# - Sushi
# - Hamburger
# Hobbies:
# - dance
# - fishkeeping
# - hunting
#
# Person person3:
# First_name: Martina
# Last_name: Nielsen
# Age: 21
# Hometown: Sydney
# Favourite_foods:
# - Assam Laksa
# - Ice cream
# - Donuts
# Hobbies:
# - singing
# - cycling
# - traveling
#
# Person person4:
# First_name: Martina
# Last_name: Nielsen
# Age: 25
# Hometown: Sydney
# Favourite_foods:
# - Assam Laksa
# - Ice cream
# - Donuts
# Hobbies:
# - singing
# - cycling
# - traveling
#
# Person person5:
# First_name: Anisha
# Last_name: Mahoney
# Age: 30
# Hometown: Paris
# Favourite_foods:
# - Lobster
# - Croissant
# - Lasagna
# Hobbies:
# - baking
# - scuba diving
# - crochet
